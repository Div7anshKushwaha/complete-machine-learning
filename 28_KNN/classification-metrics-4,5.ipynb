# %% [markdown]
# # Breast Cancer Classification Metrics

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

# %%
# Load dataset
df = pd.read_csv(r"C:\Users\divya\OneDrive\DS\Machine Learning\27_Regularization\breast cancer\data.csv")

# Display first 5 rows
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Check columns
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
# Remove unnecessary column if present
if 'Unnamed: 32' in df.columns:
    df.drop(columns=['Unnamed: 32'], inplace=True)

# Remove id column if present
if 'id' in df.columns:
    df.drop(columns=['id'], inplace=True)

df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Encode target column
encoder = LabelEncoder()

df['diagnosis'] = encoder.fit_transform(df['diagnosis'])

df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# Features and Target
X = df.drop(columns=['diagnosis'])
y = df['diagnosis']

print(X.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=1
)

# %%
# Logistic Regression Model
clf1 = LogisticRegression(max_iter=10000)

clf1.fit(X_train, y_train)

y_pred1 = clf1.predict(X_test)

# %%
# Decision Tree Model
clf2 = DecisionTreeClassifier(random_state=1)

clf2.fit(X_train, y_train)

y_pred2 = clf2.predict(X_test)

# %%
# Logistic Regression Metrics
print("LOGISTIC REGRESSION")

print("Accuracy :", accuracy_score(y_test, y_pred1))
print("Precision:", precision_score(y_test, y_pred1))
print("Recall   :", recall_score(y_test, y_pred1))
print("F1 Score :", f1_score(y_test, y_pred1))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred1))

print("\nClassification Report")
print(classification_report(y_test, y_pred1))
# Out:
# LOGISTIC REGRESSION
# Accuracy : 0.9473684210526315
# Precision: 0.9736842105263158
# Recall   : 0.8809523809523809
# F1 Score : 0.925
#
# Confusion Matrix
# [[71  1]
#  [ 5 37]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96        72
#            1       0.97      0.88      0.93        42
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %%
# Decision Tree Metrics
print("DECISION TREE")

print("Accuracy :", accuracy_score(y_test, y_pred2))
print("Precision:", precision_score(y_test, y_pred2))
print("Recall   :", recall_score(y_test, y_pred2))
print("F1 Score :", f1_score(y_test, y_pred2))

print("\nConfusion Matrix")
print(confusion_matrix(y_test, y_pred2))

print("\nClassification Report")
print(classification_report(y_test, y_pred2))
# Out:
# DECISION TREE
# Accuracy : 0.9473684210526315
# Precision: 0.9736842105263158
# Recall   : 0.8809523809523809
# F1 Score : 0.925
#
# Confusion Matrix
# [[71  1]
#  [ 5 37]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96        72
#            1       0.97      0.88      0.93        42
#
#     accuracy                           0.95       114
#    macro avg       0.95      0.93      0.94       114
# weighted avg       0.95      0.95      0.95       114

# %% [markdown]
# ![Screenshot 2026-05-19 232556.png](attachment:8241af55-0c71-4cd6-a6c6-2441061a2a56.png)

# %% [markdown]
# ![Screenshot 2026-05-19 223453.png](attachment:a8936f07-8e36-4f30-a291-19da1810d988.png)

# %% [markdown]
# ![Screenshot 2026-05-19 223936.png](attachment:2a9a153e-48ca-48ea-a96d-2e135c6db24d.png)

# %% [markdown]
# ![Screenshot 2026-05-19 225240.png](attachment:38f39c80-1e6f-4b4c-b8e5-9c23a82779a7.png)

# %% [markdown]
# ![Screenshot 2026-05-19 225608.png](attachment:e9c975b7-df15-43f8-b2e7-2317b9933d65.png)

# %% [markdown]
# ![Screenshot 2026-05-19 230325.png](attachment:8f9caabf-aeca-48ab-8186-c9c3ab0ae99f.png)

# %% [markdown]
# ![Screenshot 2026-05-19 224526.png](attachment:1b21f00f-4b70-4e20-be1e-426b96b9bb65.png)

# %%
#THE F-SCORE IS CLOSE TO THAT ENTITY(PR) WHOSE VALUE IS LOW CUZ IT USES Harmonic Mean
# PRECISION --> Out of all the samples predicted as Positive, how many were actually Positive?
#RECALL --> Out of all actual Positive samples, how many did the model correctly identify?
